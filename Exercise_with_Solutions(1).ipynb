# %% [markdown]
# # Live-Coding Solutions

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset

# %%
chipo = pd.read_csv("chipotle.tsv", sep = '\t')

# %% [markdown]
# ### Step 3. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 4. What is the number of rows in the dataset?

# %%
# Solution 1

chipo.shape[0]  # entries <= 4622 observations
# Out:
# 4622

# %%
# Solution 2

chipo.info() # entries <= 4622 observations
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
# order_id              4622 non-null int64
# quantity              4622 non-null int64
# item_name             4622 non-null object
# choice_description    3376 non-null object
# item_price            4622 non-null object
# dtypes: int64(2), object(3)
# memory usage: 180.6+ KB

# %% [markdown]
# ### Step 5. What is the number of columns in the dataset?

# %%
chipo.shape[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-940490163427> in <cell line: 1>()
# ----> 1 chipo.shape[1]
#
# NameError: name 'chipo' is not defined

# %% [markdown]
# ### Step 6. Print the name of all the columns.

# %%
chipo.columns
# Out:
# Index([u'order_id', u'quantity', u'item_name', u'choice_description',
#        u'item_price'],
#       dtype='object')

# %% [markdown]
# ### Step 7. Which was the most-ordered item?

# %%
c = chipo.groupby('item_name')
c = c.sum()
c = c.sort_values(['quantity'], ascending=False)
c.head(1)
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %% [markdown]
# ### Step 8. How many items were orderd in total?

# %%
total_items_orders = chipo.quantity.sum()
total_items_orders
# Out:
# 4972

# %% [markdown]
# ### Step 9. Turn the item price into a float

# %% [markdown]
# #### Step 9.a. Check the item price type

# %%
chipo.item_price.dtype
# Out:
# dtype('O')

# %% [markdown]
# #### Step 9.b. Create a lambda function and change the type of item price

# %%
dollarizer = lambda x: float(x[1:-1])
chipo.item_price = chipo.item_price.apply(dollarizer)

# %% [markdown]
# #### Step 9.c. Check the item price type

# %%
chipo.item_price.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Step 10. How many orders were made in the period?

# %%
orders = chipo.order_id.value_counts().count()
orders
# Out:
# 1834

# %% [markdown]
# ### Step 11. What is the average revenue amount per order?

# %%
Livechipo.groupby(by=['order_id']).sum().mean()['revenue']
# Out:
# 21.394231188658654

# %% [markdown]
# ### Step 12. How many different items are sold?

# %%
chipo.item_name.value_counts().count()
# Out:
# 50
